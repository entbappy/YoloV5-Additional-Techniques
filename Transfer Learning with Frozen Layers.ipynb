# %%
# %%bash
# git clone https://github.com/ultralytics/yolov5  # clone
# cd yolov5
# pip install -r requirements.txt wandb

# %% [markdown]
# ## To freeze layers
#
# Freeze list to contain all modules with 'model.0.' - 'model.9.'
#
# `python train.py --freeze 10`
#
# To Freeze all layers
#
# `python train.py --freeze 24`

# %%
# !python /content/yolov5/train.py --batch 48 --weights yolov5m.pt --data coco128.yaml --epochs 5 --cache --img 512 --hyp hyp.finetune.yaml --freeze 10
# Out:
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [01:34<00:00, 47.31s/it]
#                  all        128        929      0.701      0.697      0.728      0.538
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   0% 0/3 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        3/4        0G   0.02522   0.01253  0.006915       662       512:  33% 1/3 [01:01<02:02, 61.15s/it]/usr/local/lib/python3.7/dist-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# ...
